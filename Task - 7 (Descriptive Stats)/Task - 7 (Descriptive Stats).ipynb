# %% [markdown]
# # Descriptive Statistics
#
# In this type of statistics the data is summarised through the given obesrvations. Descriptive statistics is a way to oragnaise, represent and describe a collection of data using table,graphs and summary measures.Descriptive statistics are broken down into measures of central tendency and measures of spread (variability). Measures of central tendency include the mean, median, and mode, while measures of spread include standard deviation, variance, minimum and maximum variables, kurtosis, and skewness.
#
# In simple, Descriptive statistics is defined as some knowledge of the data to learn properties and parameters.
#
# In this session we will depply discuss about these measures. Things that we are going to discuss are **:**
# - Mean
# - Median
# - Mode
# - Variance
# - Standard Deviation
# - Correlation
# - Normal Distribution
# - Feature of Normal Distribution
# - Positively Skewed & Negatively Skewed Normal Distribution
# - Effect on Mean, Median and Mode due to Skewness
# - Explain QQ Plot and show the implementation of the same
# - Explain Box Cox and show the implementation of the same
#
# ## Measure of Central tendency
#
# ### Mean
#
# **Mean** is a measure of central tendency. Mean is nothing but the average of given data. Mean of list of numbers is caluculated as the ratio of sum of the elements in the list and the length of the lsit. Mean of a given data $x_1,x_2,x_3....,x_n-1,x_n$ is given as:
#
# $$Mean (\mu) = \frac{x_1+x_2+x_3+.......+x_n-1+x_n}{n}$$
#
# $$Mean (\mu) = \frac{Sum of all data points}{Number of data points}$$
#
# $$ Mean (\mu) = \sum_{i=1}^{n}D_{j}$$
#
# **Propertirs of mean :**
# - The mean varies less than the median or mode when samples are taken from the same population and all three measures are computed for these samples.
#
# - The mean is used in computing other statistics, such as the variance.
#
# - The mean for the data set is unique and not necessarily one of the data values.
#
# - The mean cannot be computed for the data in a frequency distribution that has an open-ended class.
#
# - The mean is affected by extremely high or low values, called outliers, and may not be the appropriate average to use in these situations.
# - Half of the data points are less than mena and other half are greater than mean if there are no outliers in the data.
#
# **Example Calculation of mean**
# Let's consider an example data of heights(cm) in a class:  {158,160,162,165,166,168,166,167,170,171}
#
#  The sum of the height's is calculated as
#  $ Sum of Data (sum) = 158+160+162+165+166+168+166+167+170+171$
#
#  $ Number of data points = 10 $
#
#  $ Mean = \frac{ 158+160+162+165+166+168+166+167+170+171 }{10} $
#
# **Code for Calculating Mean Without using any fuctions**
#  ``` python
# heights=[158,160,162,165,166,168,166,167,170,171]
# heights_sum=0
# heights_length=0
# for height in heights:
#     heights_sum+=height
#     heights_len+=1
# heights_mean=heights_sum/heights_length
# print("Mean of height : ",heights_mean,sep=" ")
# ```
# **Code for Calculating Mean**
# ``` python
# heights=[158,160,162,165,166,168,166,167,170,171]
# heights_mean=sum(heights)/len(heights)
# print("Mean of height : ",heights_mean,sep=" ")
# /* Using Numpy*/
# import numpy
# heights=numpy.array(heights)
# print("Mean of heights: ",numpy.mean(heights),sep=" ")
# ```
# ### Median
#
# **Median** is a measure of central tendency. Median is the middle value of given data when the data is sorted.
# For calculating median the data must be sorted either ascending or descending and the middle value is median. If the length of the data is odd then $(\frac{n+1}{2})^{th}$ term after sorting is the median. If the length is even then average of $(\frac{n}{2})^{th}$ and $(\frac{n}{2}+1)^{th}$ term after sorting.
# $$
# Median(X) = \left\{
#     \begin{array}\\
#         X\left[\frac{N}{2}\right] & \mbox{if } \ {N}  \ {is } \ {Odd} \\
#         \frac{X\left[\frac{N}{2}\right]+X\left[\frac{N}{2}+1\right]}{2} & \mbox{if } \ N \ is \ even \\
#     \end{array}
# \right.
# $$
# $$
# \ \ \ \ \ X	= 	Sorted\ list\ of\ values\ in\ data\ set
# $$
# $$
# \ N	= 	Number\ of\ values\ in\ data\ set
# $$
# **properties of median :**
# - Median is not dependent on all the data values in a dataset.
# - The median value is fixed by its position and is not reflected by the individual value.
# - The distance between the median and the rest of the values is less than the distance from any other point.
# - Every array has a single median.
# - Median cannot be manipulated algebraically. It cannot be weighed and combined.
# - In a grouping procedure, the median is stable.
# - Median is not applicable to qualitative data.
# - The values must be grouped and ordered for computation.
# - Median can be determined for ratio, interval and ordinal scale.
# - Outliers and skewed data have less impact on the median.
# - If the distribution is skewed, the median is a better measure when compared to mean.
#
# **Example of calculation of Median :**
# Let's consider an example data of heights(cm) in a class:  {158,160,162,165,166,168,166,167,170,171}
# Data after sorting in ascending order {158,160,162,165,166,166,167,168,170,171}
# The lenght of the data is 10 $\rightarrow$ Even
# $Median(height)=\frac{X\left[\frac{10}{2}\right]+X\left[\frac{10}{2}+1\right]}{2}={166}$
#
# **Code for Median without using any functions**
# ```python
# heights=[158,160,162,165,166,168,166,167,170,171]
# heights_length=0
# for height in heights:
#     heights_len+=1
# median_heightt=0
# if height%2==0:
#     median_height=(heights[heights_length/2]+heights[heights_length/2+1])/2
# else:
#     median_height=heights[heights_length/2]
# print("Median of heights: ",median_height,sep=" ")
# ```
# **Code for Median using functions**
# ```python
# import numpy
# heights=[158,160,162,165,166,168,166,167,170,171]
# heights=numpy.array(heights)
# print("Median of heights: ",numpy.median(heights),sep=" ")
# ```
# **Note:** Mean is done faster than median. But if outliers exists, then median is prefered since its easy, has no effect due to outliers and easy.
# ### Mode
# It is the value that appears most frequently in a data set. A set of data may have one mode ,more than one mode or no mode at all.Mode can be the same value as the mean and/or median, but this is not usually seen. Mode can be unimodel,bimodel, Trimodal & Multimodal.
#
# **A mode is defined as the value that has a higher frequency in a given set of values. It is the value that appears the most number of times.**
# $$ Mode(X)=Most\ frequently\ repeated\ value\ in\ a\ data\ set\ X$$
# **Properties of mode :**
# - Although mode is the most popular measure of central tendency, there are cases when mode remains undefined.
# - Unlike mean, it has no mathematical property.
# - Mode is affected by sampling fluctuations.
#
# **Example calculation of Mode:**
# Let's consider an example data of heights(cm) in a class:  {158,160,162,165,166,168,166,167,170,171}
# $$Mode(heights) = Most\ frequently\ repeated\ value(heights) = 166$$
# **Code for Mode without using any functions**
# ```python
# heights=[158,160,162,165,166,168,166,167,170,171]
# frequncy={}
# for i in heights:
#     if i in frequency:
#         frequency[i]+=1
#     else:
#         frequency[i]=1
# mode=0
# for i in heights:
#     if frquency[i]>mode:
#         mode=i
# print("Mode is : ",mode,sep=" ")
# ```
# **Code for Mode using functions**
# ```python
# from collections import
# from scipy import stats
# heights=[158,160,162,165,166,168,166,167,170,171]
# freq_heights=Counter(heights)
# print("Mode is :",freq_heights.most_common(),sep=" ")
# import numpy
# heights=numpy.array(heights)
# print("Mode is:",stats.mode(heights),sep=" ")
# ```
# ## Measure of spread
#
# ### Variance
# **Variance** measurement of the spread between numbers in the data set. It is also the measure of how far the dara points are from the mean.Variance is the expected value of the squared variation of a random variable from its mean value, in probability and statistics. Informally, variance estimates how far a set of numbers (random) are spread out from their mean value.
#
# $$Variance({\sigma}^2)=\frac{\sum_{i=0}^{n}(\mu-x_i)^2}{n}$$
# $$Where, \mu \rightarrow mean\ of\ the\ data$$
# $$\ \ \ \ \ \ \ \ \ \ \ n \rightarrow Size\ of\ the\ data$$
#
# Variance is the average square distance between mean and data points.
# **Properties of Variance**
# $The\ variance,\ var(X)\ of\ a\ random\ variable\ X\ has\ the\ following\ properties.$
# 1. $Var(X + C) = Var(X), where\ C\ is\ a\ constant.$
# 2. $Var(CX) = C^2.Var(X), where\ C\ is\ a\ constant.$
# 3. $Var(aX + b) = a^2.Var(X), where\ a\ and\ b\ are\ constants.$
# 4. $If X_1, X_2,……., X+n are\ n\ independent\ random\ variables,\ then\ Var(X_1 + X_2 +……+ X_n) = Var(X_1) + Var(X_2)+……+Var(X_n).$
#
# **Example of calculation of variance**
# let us consider some list of data {3, 8, 6, 10, 12, 9, 11, 10, 12, 7}.
# $ \mu = \frac{3+8+6+10+12+9+11+10+12+7}{10} = \frac{88}{10} = 8.8$
# ---
# | X  | $X-\mu$  | $(X-\mu)^2$ |
# |--- |----------| ------------|
# | 3  |   -5.8   |     33.64   |
# | 8  |   -0.8   |      0.64   |
# | 6  |   -2.8   |      7.84   |
# | 10 |    1.2   |      1.44   |
# | 12 |    3.2   |     10.24   |
# | 9  |    0.2   |      0.04   |
# | 11 |    2.2   |      4.84   |
# | 10 |    1.2   |      1.44   |
# | 12 |    3.2   |     10.24   |
# | 7  |   -1.2   |      1.44   |
# |Total|    0    |     73.6    |
#
# $Variance({\sigma}^2)=\frac{\sum_{i=0}^{n}(\mu-x_i)^2}{n}$
# $\ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ = \frac{73.6}{10}$
# $\ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ = 7.36$
# $Variance({\sigma}^2)=7.36$
# **Code for Variance without using any funcions**
# ```python
# data=[3, 8, 6, 10, 12, 9, 11, 10, 12, 7]
# mean_data=0
# len_data=0
# for i in data:
#     mean_data+=i
#     len_data+=1
# mean_data/=len_data
# variance=0
# for i in data:
#     variance+=(i-mean_data)**2
# variance/=len_data
# print("Variance of Data is:",variance,sep=" ")
# ```
# **code for variance using functions**
# ```python
# import numpy
# data=[3, 8, 6, 10, 12, 9, 11, 10, 12, 7]
# data=numpy.array(data)
# print("Variance of Data is:",numpy.var(data),sep" ")
# ```
# ### Standard Deviation
# In variance as the modulus value incerases the magnitude of the value, so we use standard deviation. So, the measure of speard is standard deviation. **Standard Deviation** is the dispersion of a dataset relative to its mean and is canculated as square root of variance.
# $$Standard Deviation(\sigma)= \sqrt{variance(\sigma^2)}$$
# $$Standard Deviation (\sigma)=\sqrt{\frac{\sum_{i=0}^{n}(\mu-x_i)^2}{n}}$$
# $$Where, \mu \rightarrow mean\ of\ the\ data$$
# $$\ \ \ \ \ \ \ \ \ \ \ n \rightarrow Size\ of\ the\ data$$
#
# **Properties of Standard Deviation**
# 1. It cannot be negative.
#
# 2. It is only used to measure spread or dispersion around the mean of a data set.
#
# 3. It shows how much variation or dispersion exists from the average value.
#
# 4. It is sensitive to outliers. A single outlier can raise σ and in turn, distort the picture of spread.
#
# 5. For data with almost the same mean, the greater the spread, the greater the standard deviation.
#
# 6. Standard deviation can be used in conjunction with the mean in order to calculate data intervals when analyzing normally distributed data.
# **Example of calculation of Standard Deviation**
# let us consider some list of data {3, 8, 6, 10, 12, 9, 11, 10, 12, 7}.
# $ \mu = \frac{3+8+6+10+12+9+11+10+12+7}{10} = \frac{88}{10} = 8.8$
# ---
# | X  | $X-\mu$  | $(X-\mu)^2$ |
# |--- |----------| ------------|
# | 3  |   -5.8   |     33.64   |
# | 8  |   -0.8   |      0.64   |
# | 6  |   -2.8   |      7.84   |
# | 10 |    1.2   |      1.44   |
# | 12 |    3.2   |     10.24   |
# | 9  |    0.2   |      0.04   |
# | 11 |    2.2   |      4.84   |
# | 10 |    1.2   |      1.44   |
# | 12 |    3.2   |     10.24   |
# | 7  |   -1.2   |      1.44   |
# |Total|    0    |     73.6    |
#
# $Variance({\sigma}^2)=\frac{\sum_{i=0}^{n}(\mu-x_i)^2}{n}$
# $\ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ = \frac{73.6}{10}$
# $\ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ = 7.36$
# $Variance({\sigma}^2)=7.36$
# $Standard Deviation(\sigma)= \sqrt{variance(\sigma^2)}$
# $\ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ = \sqrt{7.36}$
# $\ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ = 2.713$
# $Standard Deviation(\sigma)= 2.713$
# **Code for Standard Deviation without using any funcions**
# ```python
# data=[3, 8, 6, 10, 12, 9, 11, 10, 12, 7]
# mean_data=0
# len_data=0
# for i in data:
#     mean_data+=i
#     len_data+=1
# mean_data/=len_data
# variance=0
# for i in data:
#     variance+=(i-mean_data)**2
# variance/=len_data
# Std=variance**0.5
# print("Standard Deviation of Data is:",std,sep=" ")
# ```
# **code for Standard Deviation using functions**
# ```python
# import numpy
# data=[3, 8, 6, 10, 12, 9, 11, 10, 12, 7]
# data=numpy.array(data)
# print("Standard Deviation of Data is:",numpy.std(data),sep" ")
# ```
# ## Correlation Coefficient
# Correlation Coefficient is a statistical concept, which helps in establishing a relation between predicted and actual values obtained in a statistical experiment. The calculated value of the correlation coefficient explains the exactness between the predicted and actual values.
# Correlation Coefficient value always lies between -1 to +1. If correlation coefficient value is positive, then there is a similar and identical relation between the two variables. Else it indicates the dissimilarity between the two variables.
# The covariance of two variables divided by the product of their standard deviations gives Pearson’s correlation coefficient. It is usually represented by $\rho$
# **It is also called as dependence or pearson correlation coefficient.**
# When two sets of data are strongly linked together we stay that they have a High correlation. The correlation is positive when the value incrases together. The correlation is negative, when one value decreases as the other increases. Thr world correlation is made of co-(together) and relation.
# $$ \rho(x,y) = \frac{COV(X,Y)}{\sigma_X*\sigma_Y}$$
# $$ -1 \le \rho \le +1 $$
# $$Where, COV(X,Y) \rightarrow mean\ Covariance\ of\ X\ and\ Y $$
# $$ \sigma_X\ and\ \sigma_Y\ are\ standard\ deviation\ of\ X\ and\ Y\ respectively$$
#
# **Covariance**
# Covariance is a measure of the relationship between two random variables and to what extent, they change together. Or we can say, in other words, it defines the changes between the two variables, such that change in one variable is equal to change in another variable. This is the property of a function of maintaining its form when the variables are linearly transformed. Covariance is measured in units, which are calculated by multiplying the units of the two variables.
# Types of Covariance
# Covariance can have both positive and negative values. Based on this, it has two types:
# 1. Positive Covariance
# 2. Negative Covariance
#
# Positive Covariance
# If the covariance for any two variables is positive, that means, both the variables move in the same direction. Here, the variables show similar behaviour. That means, if the values (greater or lesser) of one variable corresponds to the values of another variable, then they are said to be in positive covariance.
# Negative Covariance
# If the covariance for any two variables is negative, that means, both the variables move in the opposite direction. It is the opposite case of positive covariance, where greater values of one variable correspond to lesser values of another variable and vice-versa.
# $$COV(X,Y) = \frac{\sum_{i=0}^{N}(X_i-\mu_X)*(Y_i-\mu_Y)}{N}$$
# $$Where,\ \mu_X\ and\ \mu_Y\ are\ the\ means\ of\ X\ and\ Y$$
# $$ N\ is\ the\ size\ of\ X\ and\ Y(X\ and\ Y\ are\ equal\ in\ size)$$
#
# ![Alt Text](https://programmathically.com/wp-content/uploads/2021/01/covariance-1024x378.png "Optional Title")
#
#
# **Example of calculation of Covariance**
# Let us consider two variables X and Y for calculating covariance between them.
# ____
# |  X  |  Y  | $X-\mu_x$ | $Y-\mu_y$ | $(X-\mu_x)*(Y-\mu_y)$ |
# |-----|-----|-----------|-----------|-----------------------|
# |  2  |  5  |   -15.67  |   -20.5   |        321.235        |
# |  8  | 12  |    -9.67  |   -13.5   |        130.545        |
# | 18  | 18  |     0.33  |    -7.5   |         -2.475        |
# | 20  | 23  |     2.33  |    -2.5   |         -5.825        |
# | 28  | 45  |    10.33  |    19.5   |        201.435        |
# | 30  | 50  |    12.33  |    24.5   |        302.085        |
#
# $ Mean of X(\mu_X) = 17.67$
# $ Mean of Y(\mu_Y) = 25.5$
# $Number of observations (N)=6$
# $COV(X,Y) = \frac{\sum_{i=0}^{N}(X_i-\mu_X)*(Y_i-\mu_Y)}{N}$
# $\ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \  =\frac{946.98}{6}$
# $\ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \ \  = 157.83$
# $COV(X,Y) = 157.83$
# **Code for covariance without using functions**
# ```python
#
# X_mean=0
# Y_mean=0
# n=0
# for i in X:
#     X_mean+=X
#     n+=1
# for i in Y:
#     Y_mean+=i
# X_mean/=n
# Y_mean/=n
# cov_x_y=0
# for i in range(n):
#     cov_x_y+=(X[i]-X_mean)*(Y[i]-Y_mean)
# cov_x_y/=n
# print("Covariance of X and Y is :",cov_x_y,sep=" ")
# ```
# **Code for covariance using functions**
# ```python
# import numpy
# X=[2,8,18,20,28,30]
# Y=[5,12,18,23,45,50]
# cov_mat = np.stack((X, Y), axis = 0)
# print("Covariance of X and Y is :",np.cov(cov_mat)[0][1],sep=" ")
# ```
# There are mainly two types of correlations:
#
# 1. Positive Correlation
# 2. Negative Correlation
# **Positive Correlation** :The value of one variable increases linearly with increase in another variable. This indicates a similar relation between both the variables. So its correlation coefficient would be positive or 1 in this case.
# **Negative Correlation** :When there is a decrease in values of one variable with decrease in values of other variable. In that case, correlation coefficient would be negative.
# **Zero Correlation or No Correlation** :There is one more situation when there is no specific relation between two variables.
#
# **Properties of Correlation**
# 1. Correlation coefficient remains in the same measurement as in which the two variables are.
#
# 2. The sign which correlations of coefficient have will always be the same as the variance.
#
# 3. The numerical value of correlation of coefficient will be in between -1 to + 1. It is known as real number value.
#
# 4. The negative value of coefficient suggests that the correlation is strong and negative. And if ‘r’ goes on approaching toward -1 then it means that the relationship is going towards the negative side.
#
#    When ‘r’ approaches to the side of + 1 then it means the relationship is strong and positive. By this we can say that if +1 is the result of the correlation then the relationship is in a positive state.
#
# 5. The weak correlation is signaled when the coefficient of correlation approaches to zero. When ‘r’ is near about zero then we can deduce that the relationship is weak.
#
# 6. Correlation coefficient can be very dicey because we cannot say that the participants are truthful or not.
#
#    The coefficient of correlation is not affected when we interchange the two variables.
#
# 7. Coefficient of correlation is a pure number without effect of any units on it. It also not get affected when we add the same number to all the values of one variable. We can multiply all the variables by the same positive number. It does not affect the correlation coefficient. As we discussed, ‘r ‘is not affected by any unit because ‘r’ is a scale invariant.
#
# 8. We use correlation for measuring the association but that does not mean we are talking about causation. By this, we simply mean that when we are correlating the two variables then it might be the possibility that the third variable may be influencing them.
#
# **Pearson Correlation Coefficient Formula**
# The linear correlation coefficient defines the degree of relation between two variables and is denoted by “r”. It is also called as Cross correlation coefficient as it predicts the relation between two quantities. Now let us proceed to a statistical way of calculating the correlation coefficient.
#
# $$ r = \frac{N*\sum{XY}-(\sum{X}*\sum{Y})}{\sqrt{ \left[N*\sum{x^2}-(\sum{x})^2 \right]*[N*\sum{y^2}-(\sum{y})^2 }]} $$
# $$Where, N= Number\ of\ Observations$$
#
# **Example of calculation of Correlation**
# Let us consider two variables X and Y for calculating correlation between them.
# ____
# | $X$ | $Y$ | $X*Y$ | $X^2$ | $Y^2$ |
# |-----|-----|-------|-------|-------|
# | 50  | 3.1 |  155  |  2500 | 9.16  |
# | 51  | 3.2 |  163.2|  2601 | 10.24 |
# | 52  | 3.3 |  171.6|  2704 | 10.89 |
# | 52  | 3.4 |  180.2|  2809 | 11.56 |
# | 53  | 3.5 |  189  |  2916 | 12.25 |
#
# $\sum X = 260$
# $\sum y = 16.5$
# $\sum {XY} = 859$
# $\sum X^2 = 13530 $
# $\sum Y^2 = 54.55$
# Now Sbustituting in COrrelation coefficient formula:
# $ r = \frac{N*\sum{XY}-(\sum{X}*\sum{Y})}{\sqrt{ \left[N*\sum{x^2}-(\sum{x})^2 \right]*[N*\sum{y^2}-(\sum{y})^2 }]} $
# $ r = \frac{(5*859)-(260*16.5)}{\sqrt{[(5*13530)-(260)^2)]*[(5*54.5)-(16.5)^2]}}$
# $ r = 1$
# **This shows a positive correlation coefficient.**
#
# **Code for correlation without using functions**
# ```python
#
# X_mean=0
# Y_mean=0
# n=0
# for i in X:
#     X_mean+=X
#     n+=1
# for i in Y:
#     Y_mean+=i
# X_mean/=n
# Y_mean/=n
# cov_x_y=0
# for i in range(n):
#     cov_x_y+=(X[i]-X_mean)*(Y[i]-Y_mean)
# cov_x_y/=n
# std_X=0
# for i in X:
#     std_X+=(i-X_mean)**2
# std_X/=n
# std_X=std_x**0.5
# std_Y=0
# for i in Y:
#     std_XY+=(i-Y_mean)**2
# std_Y/=n
# std_Y=std_Y**0.5
# corr_x_y=cov_x_y/(std_X*std_Y)
# ```
# **Code for Correlation using functions**
# ```python
# import numpy
# X=[2,8,18,20,28,30]
# Y=[5,12,18,23,45,50]
# print("Covariance of X and Y is :",np.corrcoef(X,Y)[0][1],sep=" ")
# ```
#
# # Normal Distribution
#
# A function that represents the distribution of many random variables as a symmetrical bell-shaped curved graph. Also called as Gausian Distribution. It is probabilty distribution that is symmetric about the mean. It shows the data which is near to the mean are more frequent in occurance than the data far from the mean.
# **Impotance of Normal Distiribution**
# **Normal distributions** are important in statistics and are often used in the natural and social sciences to represent real-valued random variables whose distributions are not known. Their importance is partly due to the central limit theorem. It states that, under some conditions, the average of many samples (observations) of a random variable with finite mean and variance is itself a random variable—whose distribution converges to a normal distribution as the number of samples increases. Therefore, physical quantities that are expected to be the sum of many independent processes, such as measurement errors, often have distributions that are nearly normal.
#
# Moreover, Gaussian distributions have some unique properties that are valuable in analytic studies. For instance, any linear combination of a fixed collection of normal deviates is a normal deviate. Many results and methods, such as propagation of uncertainty and least squares parameter fitting, can be derived analytically in explicit form when the relevant variables are normally distributed.
# **It occurs in nature frequently**
#
# **Standard normal distribution**
# The simplest case of a normal distribution is known as the standard normal distribution. This is a special case when $\mu$ = 0  and $\sigma$ = 1 , and it is described by this probability density function:
# $$ \varphi = \frac{\exp{-\frac{X^2}{2}}}{\sqrt{2\pi}} $$
# Here, the factor $\frac{1}{\sqrt{2\pi}}$ ensures that the total area under the curve $ \varphi(x)$ is equal to one.
# The factor $\frac{1}{2}$ in the exponent ensures that the distribution has unit variance (i.e., variance being equal to one), and therefore also unit standard deviation.
# This function is symmetric around $x=0$ where it attains its maximum value $\frac{1}{\sqrt{2\pi}}$ and has inflection points at $x=+1$ and $x=-1$
#
# **General normal distribution**
# Every normal distribution is a version of the standard normal distribution, whose domain has been stretched by a factor $\sigma$ (the standard deviation) and then translated by $\mu$(the mean value):
# $$f(x\mid\mu,\sigma)={\frac{1}{\sigma}\varphi\left(\frac{x-\mu}{\sigma}\right)}$$
# The probability density must be scaled by $\frac{1}{\sigma}$ so that the integral is still 1.
# **Notation**
# The probability density of the standard Gaussian distribution (standard normal distribution, with zero mean and unit variance) is often denoted with the Greek letter $\phi$.The alternative form of the Greek letter phi,$\varphi$ is also used quite often.
# The normal distribution is often referred to as $N(\mu,\sigma)$ or $\mathcal {N}(\mu,\sigma)$. Thus when a random variable $X$ is normally distributed with mean $\mu$ and standard deviation $\sigma$. one may write
# $$X \sim \mathcal {N}(\mu,\sigma)$$
# **Cumulative distribution function**
# The cumulative distribution function (CDF) of the standard normal distribution, usually denoted with the capital Greek letter $\phi$ is the integral
# $$\phi(x) = {\frac{1}{\sqrt{2\pi}}\int_{-inf}^{x}\exp^{-\frac{t^2}{2}}dt}$$
# The related error function gives the probability of a random variable, with normal distribution of mean 0 and variance $\frac{1}{2}$ falling in the range $[-x,x]$ That is:
# $$erf(x) = \frac{2}{\sqrt{\pi}}\int_{0}^{x}\exp^{-\frac{t^2}{2}}dt$$
# The two functions are closely related, namely
# $$ \phi(x) = \frac{1}{2}(1+erf(\frac{x}{\sqrt{2}})) $$
# For a generic normal distribution with density f is
# $$F(x) = \phi(\frac{x-\mu}{\sigma}) = \frac{1}{2}(1+erf(\frac{x-\mu}{\sqrt{2}\sigma})) $$
#
# **Properties of Normal Distribution**
#
# ![Alt Text](https://upload.wikimedia.org/wikipedia/commons/thumb/2/25/The_Normal_Distribution.svg/1280px-The_Normal_Distribution.svg.png "Optional Title")
#
# 1. It is Symmetric : A normal distrivution comes with a perfectly symmetrical shape. This means that the distribution curvve can be divided in middle to produce two equal halves. The symmetric shape occurs when one half of the observations fall on each side of the curve.
# 2. The Mean, Median and Mode are Equal. The middle point of a normal distribution us the point with maximum frequency which means that it possesses the most observations of the variable. The midpoint is also thr=e point where these three measures fall. The measures are usually equal in a perfectly (Normal) distribution.
# 3. It looks like a bell-shaped curve
# 4. $X \sim \mathcal {N}(\mu,\sigma)$ $\mu and \sigma$ can be found easily.
# 5. Emperical Rule(68-95-99.7 RULE): In nornally distributed data, there is a constant proportion if distance lying under the curve between the mean and specific number of standard deviations from the mean.This can be seen in above figure.
#     - 68% of all the cases fall with in $+-\sigma$ from $\mu$
#     - 95% of all the cases fall with in $+-2\sigma$ from $\mu$
#     - 97.7% of all the cases fall with in $+-3\sigma$ from $\mu$
# 6. Skweness of normal distribution: we will discuss about skweness in detailed. what are its effect on mean, median,Mode and discuss about differnt types of skweness of a normal distibution.
# **Skewness**
# It is a coefficient that measures how different a distribution is from a normal distribution. It is thr measure of symmetry of normal distribution.Skewness refers to a distortion or asymmetry that deviates from the symmetrical bell curve, or normal distribution, in a set of data. If the curve is shifted to the left or to the right, it is said to be skewed. Skewness can be quantified as a representation of the extent to which a given distribution varies from a normal distribution. A normal distribution has a skew of zero, while a lognormal distribution, for example, would exhibit some degree of right-skew.
# ![Alt Text](https://www.allaboutcircuits.com/uploads/thumbnails/Skewness_Feature.jpg "Optional Title")
#
# Consider the two distributions in the figure just below. Within each graph, the values on the right side of the distribution taper differently from the values on the left side. These tapering sides are called tails, and they provide a visual means to determine which of the two kinds of skewness a distribution has:
#
# 1. negative skew: The left tail is longer; the mass of the distribution is concentrated on the right of the figure. The distribution is said to be left-skewed, left-tailed, or skewed to the left, despite the fact that the curve itself appears to be skewed or leaning to the right; left instead refers to the left tail being drawn out and, often, the mean being skewed to the left of a typical center of the data. A left-skewed distribution usually appears as a right-leaning curve.[1]
# 2. positive skew: The right tail is longer; the mass of the distribution is concentrated on the left of the figure. The distribution is said to be right-skewed, right-tailed, or skewed to the right, despite the fact that the curve itself appears to be skewed or leaning to the left; right instead refers to the right tail being drawn out and, often, the mean being skewed to the right of a typical center of the data. A right-skewed distribution usually appears as a left-leaning curve
#
# A unimodal distribution with zero value of skewness does not imply that this distribution is symmetric necessarily. However, a symmetric unimodal or multimodal distribution always has zero skewness.
# **Effect on Mean, Median and Mode due to Skewness**
# ![Alt Text](https://upload.wikimedia.org/wikipedia/commons/thumb/c/cc/Relationship_between_mean_and_median_under_different_skewness.png/434px-Relationship_between_mean_and_median_under_different_skewness.png "Optional Title")
# The observation from the above figure tells us that if the distribution of data is skewed to the left, the mean is less than the median, which is often less than the mode. If the distribution of data is skewed to the right, the mode is often less than the median, which is less than the mean.
# Mean is affected by outliers. Mean is attracted towords them. So that is why is moves toword the skewed side. If it is positively skewed then mean is attracted towards right and if it is negatively skewed mean is attracked towards the leftside.
# Median will be same as it is not affected by any outliers as it is the middle values after sorting the data.
# Mode is canged opssite to the mean. It it is postively skewed data the mode is moved toward   if it is negatively skewed then the mode is moved towards right.
# Let us concider three cases Zero skewed, positively skewed and negatively skewed normal distibutions.
# For Zero skewed normal distibutions mean, median and mode be $\mu_0,\ Med_0,\ and\ Mode_0$.
# For Posivtely skewed normal distibutions mean, median and mode be $\mu_1,\ Med_1,\ and\ Mode_1$
# For Negatively skewed normal distibutions mean, median and mode be $\mu_{-1},\ Med_{-1},\ and\ Mode_{-1}$
# when compared with eachother :
# $$\mu_0 = Med_0 = Mode_0$$
# $$\mu_1\gt Med_1\gt Mode_1$$
# $$\mu_{-1} \lt Med_{-1} \lt Mode_{-1}$$
#
# **How to check wethre a distribution in a Normal Distribution or not?**
#
# **Q-Q Plot** is used to see graphically wether a distribution is normally distributed or not.
#
# **Q-Q PLOT(Quantile-Quantile)**
# ![Alt Text](https://upload.wikimedia.org/wikipedia/commons/thumb/1/11/Normal_exponential_qq.svg/300px-Normal_exponential_qq.svg.png "Optional Title")
# A Q–Q plot is a plot of the quantiles of two distributions against each other, or a plot based on estimates of the quantiles. The pattern of points in the plot is used to compare the two distributions.
# The main step in constructing a Q–Q plot is calculating or estimating the quantiles to be plotted. If one or both of the axes in a Q–Q plot is based on a theoretical distribution with a continuous cumulative distribution function (CDF), all quantiles are uniquely defined and can be obtained by inverting the CDF. If a theoretical probability distribution with a discontinuous CDF is one of the two distributions being compared, some of the quantiles may not be defined, so an interpolated quantile may be plotted. If the Q–Q plot is based on data, there are multiple quantile estimators in use. Rules for forming Q–Q plots when quantiles must be estimated or interpolated are called plotting positions.
# A simple case is where one has two data sets of the same size. In that case, to make the Q–Q plot, one orders each set in increasing order, then pairs off and plots the corresponding values. A more complicated construction is the case where two data sets of different sizes are being compared. To construct the Q–Q plot in this case, it is necessary to use an interpolated quantile estimate so that quantiles corresponding to the same underlying probability can be constructed.
# **Steps for plotting QQ Plot**
# 1. Sort all the values of X which is a Standard Normal Distribution $X \sim \mathcal {N}(0,1)$  should hold true.
# 2. observed quantity of given distribution
#     - Given randon Variable sort all the values Y
#     - $Y \sim Distribution$ (Does Y follows Normal distribution or not)
# 3. As per the data Q-Q plot is Plotted.
# 4. If thevalue/dots lie on the refernce line i.e, on $45^{\circ}\$ line, then Y is said to be followed a Normal Distribution.
# **Code for implementing Q-Q Plot**
# ```python
# from scipy import stats
# stats.probplot(X_Variable_to Check, dist="norm", plot=plt)
# ```
#
# **How to tansform a distribution to normal distribution**
#
# Many statistical tests and intervals are based on the assumption of normality. The assumption of normality often leads to tests that are simple, mathematically tractable, and powerful compared to tests that do not make the normality assumption. Unfortunately, many real data sets are in fact not approximately normal. However, an appropriate transformation of a data set can often yield a data set that does follow approximately a normal distribution. This increases the applicability and usefulness of statistical techniques based on the normality assumption.
#
# The Box-Cox transformation is a particulary useful family of transformations. It is defined as:
# $$ T(Y) = \frac{(Y^\lambda-1)}{\lambda} $$
# where Y is the response variable and $\lambda$ is the transformation parameter. For $\lambda$ = 0, the natural $\log$ of the data is taken instead of using the above formula.
# Given a particular transformation such as the Box-Cox transformation defined above, it is helpful to define a measure of the normality of the resulting transformation. One measure is to compute the correlation coefficient of a normal probability plot. The correlation is computed between the vertical and horizontal axis variables of the probability plot and is a convenient measure of the linearity of the probability plot (the more linear the probability plot, the better a normal distribution fits the data).
#
# The Box-Cox normality plot is a plot of these correlation coefficients for various values of the $\lambda$ parameter. The value of $\lambda$ corresponding to the maximum correlation on the plot is then the optimal choice for $\lambda$.
# ![Alt Text](https://onlinestatbook.com/2/transformations/graphics/box-cox_fig1.jpg "Optional Title")
# ```python
# from scipy import stats
# transformed, l = stats.boxcox(Distribution)
# ```

# %%
import pandas as pd
import numpy as np
from scipy import stats
import matplotlib.pyplot as plt
import seaborn as sns

# %%
data=pd.read_csv('data.csv')
data.head()
# Out:
#    Mthly_HH_Income  Mthly_HH_Expense  No_of_Fly_Members  Emi_or_Rent_Amt  \
# 0             5000              8000                  3             2000
# 1             6000              7000                  2             3000
# 2            10000              4500                  2                0
# 3            10000              2000                  1                0
# 4            12500             12000                  2             3000
#
#    Annual_HH_Income Highest_Qualified_Member  No_of_Earning_Members
# 0             64200           Under-Graduate                      1
# 1             79920               Illiterate                      1
# 2            112800           Under-Graduate                      1
# 3             97200               Illiterate                      1
# 4            147000                 Graduate                      1

# %%
def mean(data_list):
    sum_data=0
    len_data=0
    for i in data_list:
        sum_data+=i
        len_data+=1
    return sum_data/len_data

# %%
for col in ['Mthly_HH_Income', 'Mthly_HH_Expense','Emi_or_Rent_Amt', 'Annual_HH_Income']:
    print("Mean of",col,"is :",mean(list(data[col])),sep=" ")
# Out:
# Mean of Mthly_HH_Income is : 41558.0
# Mean of Mthly_HH_Expense is : 18818.0
# Mean of Emi_or_Rent_Amt is : 3060.0
# Mean of Annual_HH_Income is : 490019.04

# %%
def mean_function(data_list):
    return sum(data_list)/len(data_list)

# %%
for col in ['Mthly_HH_Income', 'Mthly_HH_Expense','Emi_or_Rent_Amt', 'Annual_HH_Income']:
    print("Mean of",col,"is :",mean_function(list(data[col])),sep=" ")
# Out:
# Mean of Mthly_HH_Income is : 41558.0
# Mean of Mthly_HH_Expense is : 18818.0
# Mean of Emi_or_Rent_Amt is : 3060.0
# Mean of Annual_HH_Income is : 490019.04

# %%
def median(data_list):
    len_data=0
    for i in data_list:
        len_data+=1
    data_list.sort()
    if len_data%2==0:
        return(data_list[(len_data//2)-1]+data_list[len_data//2])/2
    return data_list[int(len_data/2)-1]

# %%
for col in ['Mthly_HH_Income', 'Mthly_HH_Expense','Emi_or_Rent_Amt', 'Annual_HH_Income']:
    print("Median of",col,"is :",median(list(data[col])),sep=" ")
# Out:
# Median of Mthly_HH_Income is : 35000.0
# Median of Mthly_HH_Expense is : 15500.0
# Median of Emi_or_Rent_Amt is : 0.0
# Median of Annual_HH_Income is : 447420.0

# %%
def median_function(data_list):
    return np.median(np.array(data_list))

# %%
for col in ['Mthly_HH_Income', 'Mthly_HH_Expense','Emi_or_Rent_Amt', 'Annual_HH_Income']:
    print("Median of",col,"is :",median_function(list(data[col])),sep=" ")
# Out:
# Median of Mthly_HH_Income is : 35000.0
# Median of Mthly_HH_Expense is : 15500.0
# Median of Emi_or_Rent_Amt is : 0.0
# Median of Annual_HH_Income is : 447420.0

# %%
def mode(dat_list):
    freq={}
    for i in dat_list:
        if i in freq:
            freq[i]+=1
        else:
            freq[i]=1
    count=-1
    mode=0
    for i in freq:
        if freq[i]>count:
            count=freq[i]
            mode=i
    return mode

# %%
for col in ['No_of_Fly_Members','No_of_Earning_Members']:
    print("Mode of",col,"is :",mode(list(data[col])),sep=" ")
# Out:
# Mode of No_of_Fly_Members is : 4
# Mode of No_of_Earning_Members is : 1

# %%
def mode_function(data_list):
    return stats.mode(np.array(data_list))[0]

# %%
for col in ['No_of_Fly_Members','No_of_Earning_Members']:
    print("Mode of",col,"is :",mode_function(list(data[col])),sep=" ")
# Out:
# Mode of No_of_Fly_Members is : [4]
# Mode of No_of_Earning_Members is : [1]

# %%
def variance(data_list):
    mean_data=mean(data_list)
    variance=0
    len_data=0
    for i in data_list:
        variance+=(i-mean_data)**2
        len_data+=1
    return variance/len_data

# %%
for col in ['Mthly_HH_Income', 'Mthly_HH_Expense','Emi_or_Rent_Amt', 'Annual_HH_Income']:
    print("Variance of",col,"is :",variance(list(data[col])),sep=" ")
# Out:
# Variance of Mthly_HH_Income is : 667478836.0
# Variance of Mthly_HH_Expense is : 143249876.0
# Variance of Emi_or_Rent_Amt is : 38176400.0
# Variance of Annual_HH_Income is : 100437186889.95831

# %%
def variance_funtion(data_list):
    return np.var(np.array(data_list))

# %%
for col in ['Mthly_HH_Income', 'Mthly_HH_Expense','Emi_or_Rent_Amt', 'Annual_HH_Income']:
    print("Variance of",col,"is :",variance_funtion(list(data[col])),sep=" ")
# Out:
# Variance of Mthly_HH_Income is : 667478836.0
# Variance of Mthly_HH_Expense is : 143249876.0
# Variance of Emi_or_Rent_Amt is : 38176400.0
# Variance of Annual_HH_Income is : 100437186889.9584

# %%
def standard_deviation(data_list):
    std=variance(data_list)**0.5
    return std

# %%
for col in ['Mthly_HH_Income', 'Mthly_HH_Expense','Emi_or_Rent_Amt', 'Annual_HH_Income']:
    print("Standarf Deviation of",col,"is :",standard_deviation(list(data[col])),sep=" ")
# Out:
# Standarf Deviation of Mthly_HH_Income is : 25835.611779092826
# Standarf Deviation of Mthly_HH_Expense is : 11968.704023410388
# Standarf Deviation of Emi_or_Rent_Amt is : 6178.705366013175
# Standarf Deviation of Annual_HH_Income is : 316918.26531451027

# %%
def standarf_deviation_function(data_list):
    return np.std(np.array(data_list))

# %%
for col in ['Mthly_HH_Income', 'Mthly_HH_Expense','Emi_or_Rent_Amt', 'Annual_HH_Income']:
    print("Standarf Deviation of",col,"is :",standarf_deviation_function(list(data[col])),sep=" ")
# Out:
# Standarf Deviation of Mthly_HH_Income is : 25835.611779092826
# Standarf Deviation of Mthly_HH_Expense is : 11968.704023410388
# Standarf Deviation of Emi_or_Rent_Amt is : 6178.705366013175
# Standarf Deviation of Annual_HH_Income is : 316918.2653145104

# %%
def covariance(data_x,data_y):
    mean_x=mean(data_x)
    mean_y=mean(data_y)
    std_x=standard_deviation(data_x)
    std_y=standard_deviation(data_y)
    cov=0
    for i in range(len(data_x)):
        cov+=(data_x[i]-mean_x)*(data_y[i]-mean_y)
    cov/=len(data_x)
    return cov

# %%
for col1 in ['Mthly_HH_Income', 'Mthly_HH_Expense','Emi_or_Rent_Amt', 'Annual_HH_Income']:
    for col2 in ['Mthly_HH_Income', 'Mthly_HH_Expense','Emi_or_Rent_Amt', 'Annual_HH_Income']:
        print("covariance between",col1,"and",col2,"is :",covariance(list(data[col1]),list(data[col2])))
# Out:
# covariance between Mthly_HH_Income and Mthly_HH_Income is : 667478836.0
# covariance between Mthly_HH_Income and Mthly_HH_Expense is : 200749556.0
# covariance between Mthly_HH_Income and Emi_or_Rent_Amt is : 5902520.0
# covariance between Mthly_HH_Income and Annual_HH_Income is : 7944726511.680006
# covariance between Mthly_HH_Expense and Mthly_HH_Income is : 200749556.0
# covariance between Mthly_HH_Expense and Mthly_HH_Expense is : 143249876.0
# covariance between Mthly_HH_Expense and Emi_or_Rent_Amt is : 29970920.0
# covariance between Mthly_HH_Expense and Annual_HH_Income is : 2242563305.2800007
# covariance between Emi_or_Rent_Amt and Mthly_HH_Income is : 5902520.0
# covariance between Emi_or_Rent_Amt and Mthly_HH_Expense is : 29970920.0
# covariance between Emi_or_Rent_Amt and Emi_or_Rent_Amt is : 38176400.0
# covariance between Emi_or_Rent_Amt and Annual_HH_Income is : 5317737.599999771
# covariance between Annual_HH_Income and Mthly_HH_Income is : 7944726511.680006
# ...

# %%
def cov_function(data_x,data_y):
    return np.cov(data_x,data_y)[0][1]

# %%
for col1 in ['Mthly_HH_Income', 'Mthly_HH_Expense','Emi_or_Rent_Amt', 'Annual_HH_Income']:
    for col2 in ['Mthly_HH_Income', 'Mthly_HH_Expense','Emi_or_Rent_Amt', 'Annual_HH_Income']:
        print("covariance between",col1,"and",col2,"is :",cov_function(list(data[col1]),list(data[col2])))
# Out:
# covariance between Mthly_HH_Income and Mthly_HH_Income is : 681100853.0612245
# covariance between Mthly_HH_Income and Mthly_HH_Expense is : 204846485.7142857
# covariance between Mthly_HH_Income and Emi_or_Rent_Amt is : 6022979.591836735
# covariance between Mthly_HH_Income and Annual_HH_Income is : 8106863787.428574
# covariance between Mthly_HH_Expense and Mthly_HH_Income is : 204846485.7142857
# covariance between Mthly_HH_Expense and Mthly_HH_Expense is : 146173342.85714284
# covariance between Mthly_HH_Expense and Emi_or_Rent_Amt is : 30582571.428571425
# covariance between Mthly_HH_Expense and Annual_HH_Income is : 2288329903.3469396
# covariance between Emi_or_Rent_Amt and Mthly_HH_Income is : 6022979.591836735
# covariance between Emi_or_Rent_Amt and Mthly_HH_Expense is : 30582571.428571425
# covariance between Emi_or_Rent_Amt and Emi_or_Rent_Amt is : 38955510.20408163
# covariance between Emi_or_Rent_Amt and Annual_HH_Income is : 5426262.8571426645
# ...

# %%
def correlation(data_x,data_y):
    cov=covariance(data_x,data_y)
    std_x=standard_deviation(data_x)
    std_y=standard_deviation(data_y)
    return cov/(std_x*std_y)

# %%
for col1 in ['Mthly_HH_Income', 'Mthly_HH_Expense','Emi_or_Rent_Amt', 'Annual_HH_Income']:
    for col2 in ['Mthly_HH_Income', 'Mthly_HH_Expense','Emi_or_Rent_Amt', 'Annual_HH_Income']:
        print("correlation between",col1,"and",col2,"is :",correlation(list(data[col1]),list(data[col2])))
# Out:
# correlation between Mthly_HH_Income and Mthly_HH_Income is : 1.0
# correlation between Mthly_HH_Income and Mthly_HH_Expense is : 0.6492152549316462
# correlation between Mthly_HH_Income and Emi_or_Rent_Amt is : 0.03697611093890592
# correlation between Mthly_HH_Income and Annual_HH_Income is : 0.9703154166603717
# correlation between Mthly_HH_Expense and Mthly_HH_Income is : 0.6492152549316462
# correlation between Mthly_HH_Expense and Mthly_HH_Expense is : 1.0
# correlation between Mthly_HH_Expense and Emi_or_Rent_Amt is : 0.4052802691623041
# correlation between Mthly_HH_Expense and Annual_HH_Income is : 0.5912216295468026
# correlation between Emi_or_Rent_Amt and Mthly_HH_Income is : 0.03697611093890592
# correlation between Emi_or_Rent_Amt and Mthly_HH_Expense is : 0.4052802691623041
# correlation between Emi_or_Rent_Amt and Emi_or_Rent_Amt is : 0.9999999999999998
# correlation between Emi_or_Rent_Amt and Annual_HH_Income is : 0.002715702219692466
# ...

# %%
def corr_function(data_x,data_y):
    return np.corrcoef(data_x,data_y)[0][1]

# %%
for col1 in ['Mthly_HH_Income', 'Mthly_HH_Expense','Emi_or_Rent_Amt', 'Annual_HH_Income']:
    for col2 in ['Mthly_HH_Income', 'Mthly_HH_Expense','Emi_or_Rent_Amt', 'Annual_HH_Income']:
        print("correlation between",col1,"and",col2,"is :",corr_function(list(data[col1]),list(data[col2])))
# Out:
# correlation between Mthly_HH_Income and Mthly_HH_Income is : 1.0
# correlation between Mthly_HH_Income and Mthly_HH_Expense is : 0.6492152549316462
# correlation between Mthly_HH_Income and Emi_or_Rent_Amt is : 0.03697611093890591
# correlation between Mthly_HH_Income and Annual_HH_Income is : 0.970315416660371
# correlation between Mthly_HH_Expense and Mthly_HH_Income is : 0.6492152549316462
# correlation between Mthly_HH_Expense and Mthly_HH_Expense is : 1.0
# correlation between Mthly_HH_Expense and Emi_or_Rent_Amt is : 0.4052802691623041
# correlation between Mthly_HH_Expense and Annual_HH_Income is : 0.5912216295468026
# correlation between Emi_or_Rent_Amt and Mthly_HH_Income is : 0.03697611093890591
# correlation between Emi_or_Rent_Amt and Mthly_HH_Expense is : 0.40528026916230414
# correlation between Emi_or_Rent_Amt and Emi_or_Rent_Amt is : 1.0
# correlation between Emi_or_Rent_Amt and Annual_HH_Income is : 0.0027157022196924864
# ...

# %% [markdown]
# **Q-Q Plot**

# %%
for col in ['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members','Emi_or_Rent_Amt', 'Annual_HH_Income','No_of_Earning_Members']:
    fig = plt.figure()
    ax = fig.add_subplot(111)
    stats.probplot(data[col], dist="norm", plot=plt)

# %%
for col in ['Mthly_HH_Income', 'Mthly_HH_Expense', 'No_of_Fly_Members','Emi_or_Rent_Amt', 'Annual_HH_Income','No_of_Earning_Members']:
    plt.figure(figsize=(20,10))
    sns.set_style("darkgrid")
    sns.displot(data[col],kind='kde',legend=True)

# %% [markdown]
# **Box Cox Transformation**

# %%
transformed, l = stats.boxcox(data["Annual_HH_Income"])
plt.figure(figsize=(20,10))
sns.set_style("darkgrid")
sns.displot(transformed,kind='kde',legend=True)

# %%
stats.probplot(transformed, dist="norm", plot=plt)
# Out:
# ((array([-2.20385432, -1.83293478, -1.61402323, -1.45296849, -1.32267759,
#          -1.21163342, -1.113805  , -1.02561527, -0.94475674, -0.86964726,
#          -0.79915021, -0.73241807, -0.66879925, -0.6077796 , -0.54894415,
#          -0.49195112, -0.43651377, -0.38238727, -0.32935914, -0.27724191,
#          -0.2258675 , -0.17508277, -0.12474591, -0.07472335, -0.02488719,
#           0.02488719,  0.07472335,  0.12474591,  0.17508277,  0.2258675 ,
#           0.27724191,  0.32935914,  0.38238727,  0.43651377,  0.49195112,
#           0.54894415,  0.6077796 ,  0.66879925,  0.73241807,  0.79915021,
#           0.86964726,  0.94475674,  1.02561527,  1.113805  ,  1.21163342,
#           1.32267759,  1.45296849,  1.61402323,  1.83293478,  2.20385432]),
#   array([ 58.24293824,  61.70421582,  64.96005249,  67.54329643,
#           72.38061027,  74.8726426 ,  78.06452764,  79.99898498,
#           80.27429016,  80.45631493,  82.63682662,  82.74154791,
# ...
